# %% [markdown]
# # src/pe ? BCM

# %% [markdown]
# Blockwise Causal Masking utils.

# %%
import torch
def blockwise_causal_mask(L, block=64, device=None):
    idx = torch.arange(L, device=device)
    i = idx.view(L,1); j = idx.view(1,L)
    return (j <= i)  # baseline causal (extend to blockwise if needed)
