# %% [markdown]
# # src/pe ? XPOS

# %% [markdown]
# XPOS: RoPE with gentle exponential scaling for length extrapolation.

# %%
print('Implement XPOS scaling schedule and apply to q/k (placeholder)')
