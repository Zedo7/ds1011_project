# %% [markdown]
# # src/data ? TimeSeries-PILE Loader

# %% [markdown]
# Data loader & windowing.

# %%
from pathlib import Path
import numpy as np, pandas as pd
class TimeSeriesPile:
    def __init__(self, root="./data", dataset="electricity", normalize="zscore_per_series"):
        self.root = Path(root); self.dataset = dataset; self.normalize = normalize
    def load(self):
        print("Loading dataset:", self.dataset); return None
    def make_windows(self, L=256, H=48, stride=1): pass
